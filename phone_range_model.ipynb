# %%
#import library penting
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 

# %matplotlib inline

# %%
#load dataset
data = pd.read_excel('Price Range Phone Dataset.xlsx')
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#cek jumlah data dan kolomnya
data.shape
# Out:
# (2000, 21)

# %% [markdown]
# ## EDA

# %%
#cek data kosong
data.isnull().values.any()
# Out:
# False

# %%
#Korelasi menggunakan heatmap
import seaborn as sns 

korelasi = data.corr()
features = korelasi.index
plt.figure(figsize=(20,20))

#plot heat map
g=sns.heatmap(data[features].corr(),annot=True,cmap="RdYlGn")

# %%
#Show corellation in tables
data.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
#statistika dasar
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
#Cek skewness dari data
phoneRange_zero_count =len(data.loc[data['price_range']==0])
phoneRange_one_count = len(data.loc[data['price_range']==1])
phoneRange_two_count = len(data.loc[data['price_range']==2])
phoneRange_three_count = len(data.loc[data['price_range']==3])

# %%
#view
(phoneRange_zero_count,phoneRange_one_count,phoneRange_two_count, phoneRange_three_count)
# Out:
# (500, 500, 500, 500)

# %%
#Missing value
print('total number of rows : {0}'.format(data.shape[0]))
print('total number of columns : {0}'.format(data.shape[1]))
# Out:
# total number of rows : 2000
# total number of columns : 21

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
print('Banyak baris nilai nol untuk Battery Power :{0}'.format(len(data.loc[data['battery_power']==0])))
print('Banyak baris nilai nol untuk Blue :{0}'.format(len(data.loc[data['blue']==0])))
print('Banyak baris nilai nol untuk Clock Speed :{0}'.format(len(data.loc[data['clock_speed']==0])))
print('Banyak baris nilai nol untuk Dual SIM :{0}'.format(len(data.loc[data['dual_sim']==0])))
print('Banyak baris nilai nol untuk FC :{0}'.format(len(data.loc[data['fc']==0])))
print('Banyak baris nilai nol untuk 4G :{0}'.format(len(data.loc[data['four_g']==0])))
print('Banyak baris nilai nol untuk Memory :{0}'.format(len(data.loc[data['int_memory']==0])))
print('Banyak baris nilai nol untuk m_dep :{0}'.format(len(data.loc[data['m_dep']==0])))
print('Banyak baris nilai nol untuk Mobile WT :{0}'.format(len(data.loc[data['mobile_wt']==0])))
print('Banyak baris nilai nol untuk n-Cores :{0}'.format(len(data.loc[data['n_cores']==0])))
print('Banyak baris nilai nol untuk PC :{0}'.format(len(data.loc[data['pc']==0])))
print('Banyak baris nilai nol untuk PX Height :{0}'.format(len(data.loc[data['px_height']==0])))
print('Banyak baris nilai nol untuk PX Width :{0}'.format(len(data.loc[data['px_width']==0])))
print('Banyak baris nilai nol untuk RAM :{0}'.format(len(data.loc[data['ram']==0])))
print('Banyak baris nilai nol untuk sc-H :{0}'.format(len(data.loc[data['sc_h']==0])))
print('Banyak baris nilai nol untuk sc-W :{0}'.format(len(data.loc[data['sc_w']==0])))
print('Banyak baris nilai nol untuk Talk Time :{0}'.format(len(data.loc[data['talk_time']==0])))
print('Banyak baris nilai nol untuk 3G :{0}'.format(len(data.loc[data['three_g']==0])))
print('Banyak baris nilai nol untuk TouchScreen :{0}'.format(len(data.loc[data['touch_screen']==0])))
print('Banyak baris nilai nol untuk Wi-Fi :{0}'.format(len(data.loc[data['wifi']==0])))
# Out:
# Banyak baris nilai nol untuk Battery Power :0
# Banyak baris nilai nol untuk Blue :1010
# Banyak baris nilai nol untuk Clock Speed :0
# Banyak baris nilai nol untuk Dual SIM :981
# Banyak baris nilai nol untuk FC :474
# Banyak baris nilai nol untuk 4G :957
# Banyak baris nilai nol untuk Memory :0
# Banyak baris nilai nol untuk m_dep :0
# Banyak baris nilai nol untuk Mobile WT :0
# Banyak baris nilai nol untuk n-Cores :0
# Banyak baris nilai nol untuk PC :101
# Banyak baris nilai nol untuk PX Height :2
# Banyak baris nilai nol untuk PX Width :0
# Banyak baris nilai nol untuk RAM :0
# Banyak baris nilai nol untuk sc-H :0
# Banyak baris nilai nol untuk sc-W :180
# Banyak baris nilai nol untuk Talk Time :0
# Banyak baris nilai nol untuk 3G :477
# Banyak baris nilai nol untuk TouchScreen :994
# Banyak baris nilai nol untuk Wi-Fi :986

# %%
data2 = data.copy()

# %%
#rata-rata
avg_blue = data2['blue'].mean()
avg_dualsim = data2['dual_sim'].mean()
avg_fc = data2['fc'].mean()
avg_fourg = data2['four_g'].mean()
avg_pc = data2['pc'].mean()
avg_pxheight = data2['px_height'].mean()
avg_scw = data2['sc_w'].mean()
avg_threeg = data2['three_g'].mean()
avg_touchscreen = data2['touch_screen'].mean()
avg_wifi = data2['wifi'].mean()

# %%
#now replace avg to columns
data2['blue'].replace({0:avg_blue},inplace=True)
data2['dual_sim'].replace({0:avg_dualsim},inplace=True)
data2['fc'].replace({0:avg_fc},inplace=True)
data2['four_g'].replace({0:avg_fourg},inplace=True)
data2['pc'].replace({0:avg_pc},inplace=True)
data2['px_height'].replace({0:avg_pxheight},inplace=True)
data2['sc_w'].replace({0:avg_scw},inplace=True)
data2['three_g'].replace({0:avg_threeg},inplace=True)
data2['touch_screen'].replace({0:avg_touchscreen},inplace=True)
data2['wifi'].replace({0:avg_wifi},inplace=True)

# %%
#Double check
print('Banyak baris nilai nol untuk Battery Power :{0}'.format(len(data2.loc[data2['battery_power']==0])))
print('Banyak baris nilai nol untuk Blue :{0}'.format(len(data2.loc[data2['blue']==0])))
print('Banyak baris nilai nol untuk Clock Speed :{0}'.format(len(data2.loc[data2['clock_speed']==0])))
print('Banyak baris nilai nol untuk Dual SIM :{0}'.format(len(data2.loc[data2['dual_sim']==0])))
print('Banyak baris nilai nol untuk FC :{0}'.format(len(data2.loc[data2['fc']==0])))
print('Banyak baris nilai nol untuk 4G :{0}'.format(len(data2.loc[data2['four_g']==0])))
print('Banyak baris nilai nol untuk Memory :{0}'.format(len(data2.loc[data2['int_memory']==0])))
print('Banyak baris nilai nol untuk m_dep :{0}'.format(len(data2.loc[data2['m_dep']==0])))
print('Banyak baris nilai nol untuk Mobile WT :{0}'.format(len(data2.loc[data2['mobile_wt']==0])))
print('Banyak baris nilai nol untuk n-Cores :{0}'.format(len(data2.loc[data2['n_cores']==0])))
print('Banyak baris nilai nol untuk PC :{0}'.format(len(data2.loc[data2['pc']==0])))
print('Banyak baris nilai nol untuk PX Height :{0}'.format(len(data2.loc[data2['px_height']==0])))
print('Banyak baris nilai nol untuk PX Width :{0}'.format(len(data2.loc[data2['px_width']==0])))
print('Banyak baris nilai nol untuk RAM :{0}'.format(len(data2.loc[data2['ram']==0])))
print('Banyak baris nilai nol untuk sc-H :{0}'.format(len(data2.loc[data2['sc_h']==0])))
print('Banyak baris nilai nol untuk sc-W :{0}'.format(len(data2.loc[data2['sc_w']==0])))
print('Banyak baris nilai nol untuk Talk Time :{0}'.format(len(data2.loc[data2['talk_time']==0])))
print('Banyak baris nilai nol untuk 3G :{0}'.format(len(data2.loc[data2['three_g']==0])))
print('Banyak baris nilai nol untuk TouchScreen :{0}'.format(len(data2.loc[data2['touch_screen']==0])))
print('Banyak baris nilai nol untuk Wi-Fi :{0}'.format(len(data2.loc[data2['wifi']==0])))
# Out:
# Banyak baris nilai nol untuk Battery Power :0
# Banyak baris nilai nol untuk Blue :0
# Banyak baris nilai nol untuk Clock Speed :0
# Banyak baris nilai nol untuk Dual SIM :0
# Banyak baris nilai nol untuk FC :0
# Banyak baris nilai nol untuk 4G :0
# Banyak baris nilai nol untuk Memory :0
# Banyak baris nilai nol untuk m_dep :0
# Banyak baris nilai nol untuk Mobile WT :0
# Banyak baris nilai nol untuk n-Cores :0
# Banyak baris nilai nol untuk PC :0
# Banyak baris nilai nol untuk PX Height :0
# Banyak baris nilai nol untuk PX Width :0
# Banyak baris nilai nol untuk RAM :0
# Banyak baris nilai nol untuk sc-H :0
# Banyak baris nilai nol untuk sc-W :0
# Banyak baris nilai nol untuk Talk Time :0
# Banyak baris nilai nol untuk 3G :0
# Banyak baris nilai nol untuk TouchScreen :0
# Banyak baris nilai nol untuk Wi-Fi :0

# %%
#make pairplot
sns.pairplot(data2,hue='price_range',palette='magma',height=3.5)
plt.tight_layout()

# %%
#joinplot
sns.jointplot(x='battery_power',y='price_range',data=data2,height=10,kind='kde',color='blue')
plt.tight_layout()

# %% [markdown]
# ## Apply Model

# %%
from sklearn.model_selection import train_test_split

x = data2.drop('price_range',axis=1)
y = data2['price_range']

# %%
x
# Out:
#       battery_power   blue  clock_speed  dual_sim       fc  four_g  \
# 0               842  0.495          2.2    0.5095   1.0000  0.5215
# 1              1021  1.000          0.5    1.0000   4.3095  1.0000
# 2               563  1.000          0.5    1.0000   2.0000  1.0000
# 3               615  1.000          2.5    0.5095   4.3095  0.5215
# 4              1821  1.000          1.2    0.5095  13.0000  1.0000
# ...             ...    ...          ...       ...      ...     ...
# 1995            794  1.000          0.5    1.0000   4.3095  1.0000
# 1996           1965  1.000          2.6    1.0000   4.3095  0.5215
# 1997           1911  0.495          0.9    1.0000   1.0000  1.0000
# 1998           1512  0.495          0.9    0.5095   4.0000  1.0000
# 1999            510  1.000          2.0    1.0000   5.0000  1.0000
#
#       int_memory  m_dep  mobile_wt  n_cores    pc  px_height  px_width   ram  \
# 0              7    0.6        188        2   2.0       20.0       756  2549
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x_train
# Out:
#       battery_power   blue  clock_speed  dual_sim      fc  four_g  int_memory  \
# 968            1923  0.495          0.5    1.0000  7.0000  0.5215          46
# 240             633  1.000          2.2    0.5095  4.3095  1.0000          49
# 819            1236  0.495          0.9    1.0000  2.0000  1.0000          57
# 692             781  0.495          1.1    0.5095  2.0000  0.5215          38
# 420            1456  1.000          0.5    1.0000  7.0000  0.5215           7
# ...             ...    ...          ...       ...     ...     ...         ...
# 1130           1975  1.000          1.9    1.0000  2.0000  0.5215          31
# 1294            589  1.000          0.5    0.5095  1.0000  1.0000          59
# 860            1829  1.000          0.5    0.5095  4.3095  1.0000          15
# 1459           1927  0.495          0.9    1.0000  3.0000  0.5215          11
# 1126            635  1.000          0.6    1.0000  1.0000  1.0000          50
#
# ...

# %%
x_train.shape
# Out:
# (1600, 20)

# %%
y_train.shape
# Out:
# (1600,)

# %%
x_test
# Out:
#       battery_power   blue  clock_speed  dual_sim      fc  four_g  int_memory  \
# 1860           1646  0.495          2.5    0.5095  3.0000  1.0000          25
# 353            1182  0.495          0.5    0.5095  7.0000  1.0000           8
# 1333           1972  0.495          2.9    0.5095  9.0000  0.5215          14
# 905             989  1.000          2.0    0.5095  4.0000  0.5215          17
# 1289            615  1.000          0.5    1.0000  7.0000  0.5215          58
# ...             ...    ...          ...       ...     ...     ...         ...
# 965            1379  0.495          0.5    1.0000  1.0000  0.5215          19
# 1284            991  0.495          2.0    0.5095  2.0000  1.0000          12
# 1739           1044  0.495          1.8    0.5095  4.0000  1.0000          12
# 261             728  0.495          2.7    1.0000  4.3095  0.5215          25
# 535            1185  0.495          1.9    0.5095  4.3095  0.5215          31
#
# ...

# %%
y_train
# Out:
# 968     1
# 240     2
# 819     0
# 692     3
# 420     1
#        ..
# 1130    3
# 1294    0
# 860     2
# 1459    3
# 1126    1
# Name: price_range, Length: 1600, dtype: int64

# %% [markdown]
# ## Training

# %%
from sklearn.svm import SVC

SVC_model = SVC()
SVC_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc_prediction = SVC_model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,svc_prediction))
# Out:
# [[103   2   0   0]
#  [  1  90   0   0]
#  [  0   3  87   2]
#  [  0   0   6 106]]

# %%
print(classification_report(y_test,svc_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       105
#            1       0.95      0.99      0.97        91
#            2       0.94      0.95      0.94        92
#            3       0.98      0.95      0.96       112
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.97      0.96       400
# weighted avg       0.97      0.96      0.97       400

# %% [markdown]
# ## Save Model

# %%
import pickle

pickle.dump(SVC_model,open('SVC.pkl','wb'))
